# %% [markdown]
# # importar bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # importar tabela

# %%
df = pd.read_csv('penguins.csv')

# %% [markdown]
# # manipular dataFrame

# %%
df
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 0             1     Adelie  Torgersen            39.1           18.7
# 1             2     Adelie  Torgersen            39.5           17.4
# 2             3     Adelie  Torgersen            40.3           18.0
# 3             4     Adelie  Torgersen             NaN            NaN
# 4             5     Adelie  Torgersen            36.7           19.3
# ..          ...        ...        ...             ...            ...
# 339         340  Chinstrap      Dream            55.8           19.8
# 340         341  Chinstrap      Dream            43.5           18.1
# 341         342  Chinstrap      Dream            49.6           18.2
# 342         343  Chinstrap      Dream            50.8           19.0
# 343         344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007

# %%
df.tail()
# Out:
#      Unnamed: 0    species island  bill_length_mm  bill_depth_mm  \
# 339         340  Chinstrap  Dream            55.8           19.8
# 340         341  Chinstrap  Dream            43.5           18.1
# 341         342  Chinstrap  Dream            49.6           18.2
# 342         343  Chinstrap  Dream            50.8           19.0
# 343         344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009

# %% [markdown]
# # informações da tabela

# %%
df.shape
# Out:
# (344, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
df['island'].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      168
# female    165
# Name: sex, dtype: int64

# %%
df[['sex', 'island']]
# Out:
#         sex     island
# 0      male  Torgersen
# 1    female  Torgersen
# 2    female  Torgersen
# 3       NaN  Torgersen
# 4    female  Torgersen
# ..      ...        ...
# 339    male      Dream
# 340  female      Dream
# 341    male      Dream
# 342    male      Dream
# 343  female      Dream
#
# [344 rows x 2 columns]

# %% [markdown]
# # excluir colunas

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# # NaN
# Not a Number

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
df[df['sex'].isnull()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %%
# mean, mode, median
df['bill_length_mm'].fillna(df['bill_length_mm'].mode())
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
df['sex'].fillna('T', inplace=True)

# %%
df[df['sex'] == 'T']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g sex  year
# 3            NaN   T  2007
# 8         3475.0   T  2007
# ...

# %%
df['sex'].replace('T', np.nan, inplace=True)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.shape
# Out:
# (333, 8)

# %%
df[(df.bill_depth_mm > 21) & (df.bill_length_mm > 40)]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 19  Adelie  Torgersen            46.0           21.5              194.0
# 49  Adelie      Dream            42.3           21.2              191.0
# 61  Adelie     Biscoe            41.3           21.1              195.0
#
#     body_mass_g   sex  year
# 19       4200.0  male  2007
# 49       4150.0  male  2007
# 61       4400.0  male  2008

# %%
df.query('bill_depth_mm > 21 and bill_length_mm > 40')
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 19  Adelie  Torgersen            46.0           21.5              194.0
# 49  Adelie      Dream            42.3           21.2              191.0
# 61  Adelie     Biscoe            41.3           21.1              195.0
#
#     body_mass_g   sex  year
# 19       4200.0  male  2007
# 49       4150.0  male  2007
# 61       4400.0  male  2008

# %% [markdown]
# # unique, nlargest, nsmallest

# %%
df.year.unique()
# Out:
# array([2007, 2008, 2009])

# %%
df.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
df.nlargest(2, ['body_mass_g'])
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169  Gentoo  Biscoe            49.2           15.2              221.0
# 185  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex  year
# 169       6300.0  male  2007
# 185       6050.0  male  2007

# %%
df.nsmallest(3, ['bill_length_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142  Adelie      Dream            32.1           15.5              188.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
#
#      body_mass_g     sex  year
# 142       3050.0  female  2009
# 98        2900.0  female  2008
# 70        3600.0  female  2008

# %% [markdown]
# # iloc e loc

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
df.iloc[0:3, 0:4]
# Out:
#   species     island  bill_length_mm  bill_depth_mm
# 0  Adelie  Torgersen            39.1           18.7
# 1  Adelie  Torgersen            39.5           17.4
# 2  Adelie  Torgersen            40.3           18.0

# %%
df.loc[0:3, 'species': 'bill_depth_mm']
# Out:
#   species     island  bill_length_mm  bill_depth_mm
# 0  Adelie  Torgersen            39.1           18.7
# 1  Adelie  Torgersen            39.5           17.4
# 2  Adelie  Torgersen            40.3           18.0

# %% [markdown]
# # Visualizar

# %%
# histograma
df['body_mass_g'].hist(bins=20)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
# gráfico de barra vertical
df.island.value_counts().plot(kind='bar');

# %%
# gráfico de barra horizontal
df.island.value_counts().plot(kind='barh');

# %% [markdown]
# # Groupby

# %%
df.groupby(['island', 'species']).sex.value_counts()
# Out:
# island     species    sex
# Biscoe     Adelie     female    22
#                       male      22
#            Gentoo     male      61
#                       female    58
# Dream      Adelie     male      28
#                       female    27
#            Chinstrap  female    34
#                       male      34
# Torgersen  Adelie     female    24
#                       male      23
# Name: sex, dtype: int64

# %%
df.groupby(['island', 'species']).body_mass_g.mean()
# Out:
# island     species
# Biscoe     Adelie       3709.659091
#            Gentoo       5092.436975
# Dream      Adelie       3701.363636
#            Chinstrap    3733.088235
# Torgersen  Adelie       3708.510638
# Name: body_mass_g, dtype: float64

# %%
df.groupby(['species']).bill_length_mm.mean().sort_values().plot(kind='barh');

# %%
df.groupby(['island', 'species']).sex.value_counts().plot(kind='pie');

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %% [markdown]
# # Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
# year                     0.032657      -0.048182           0.151068
#
#                    body_mass_g      year
# bill_length_mm        0.589451  0.032657
# bill_depth_mm        -0.472016 -0.048182
# flipper_length_mm     0.872979  0.151068
# body_mass_g           1.000000  0.021862
# year                  0.021862  1.000000

# %% [markdown]
# # Dummies / One-Hot-Encode

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
df = pd.get_dummies(df, columns=['sex'])

# %% [markdown]
# # factorize

# %%
df['species'], _ = pd.factorize(df['species'])

# %%
df.head()
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        0  Torgersen            39.1           18.7              181.0
# 1        0  Torgersen            39.5           17.4              186.0
# 2        0  Torgersen            40.3           18.0              195.0
# 4        0  Torgersen            36.7           19.3              193.0
# 5        0  Torgersen            39.3           20.6              190.0
#
#    body_mass_g  year  sex_female  sex_male
# 0       3750.0  2007           0         1
# 1       3800.0  2007           1         0
# 2       3250.0  2007           1         0
# 4       3450.0  2007           1         0
# 5       3650.0  2007           0         1

# %% [markdown]
# # Save

# %%
df.to_csv('penguinSSS.csv', index=False)
